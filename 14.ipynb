# %% [markdown]
# # The Python Challenge
#
# ## Level 14 - walk around
#
# ### Url: http://www.huge:file@pythonchallenge.com/pc/return/italy.html

# %% [markdown]
# F12注释提示 `<!-- remember: 100*100 = (100+99+99+98) + (...  -->`
#
# 底下有一张 `wire.jpg` 应该是用来解题的。
#
# 根据题图这个螺旋面包，可以理解这个算式的意义是“向内螺旋”，比如从左上角出发，向右走100像素，接下来向右转向下走99像素到底，右转向左99像素到左下，这样一直往内螺旋。

# %%
from IPython.display import display
from PIL import Image
import requests

# %%
with Image.open(
        requests.get(
            "http://huge:file@www.pythonchallenge.com/pc/return/wire.png",
            stream=True).raw) as im:
    display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=10000x1 at 0x1EED19BD370>

# %%
target = Image.new(mode='RGB', size=(100, 100))
direction = [(1, 0), (0, 1), (-1, 0), (0, -1)]
toward = 0
pos = (0, 0)
for i in range(10000):
    pixel = im.getpixel((i, 0))
    target.putpixel(pos, pixel)
    nextpos = (pos[0] + direction[toward][0], pos[1] + direction[toward][1])
    if (nextpos[0] < 0 or nextpos[0] >= 100 or nextpos[1] < 0
            or nextpos[1] >= 100) or target.getpixel(nextpos) != (0, 0, 0):
        toward = (toward + 1) % 4
    pos = (pos[0] + direction[toward][0], pos[1] + direction[toward][1])
display(target)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1EED119C250>

# %% [markdown]
# 尝试 `/cat.html` 网页，该网页存在，有一张上图的完整版 (http://www.pythonchallenge.com/pc/return/uzi.jpg) 显示这只猫在原图的右边，左边还有只黑猫。
#
# 以及一行文本：
#
# > and its name is uzi. you'll hear from him later.
#
# 卧槽，乌兹！
#
# 不过这个later让我有点警觉，可能这张图会是一个伏笔，稍微F12一下没看到什么有用的，先作罢。

# %%
with Image.open(
        requests.get(
            "http://huge:file@www.pythonchallenge.com/pc/return/uzi.jpg",
            stream=True).raw) as im:
    display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x1EED19A2520>

# %% [markdown]
# ## Next Level:
#
# ### Url: http://huge:file@www.pythonchallenge.com/pc/return/uzi.html
