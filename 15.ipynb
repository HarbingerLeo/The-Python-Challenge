# %% [markdown]
# # The Python Challenge
#
# ## Level 15 - whom?
#
# ### Url: http://huge:file@www.pythonchallenge.com/pc/return/uzi.html

# %%
from IPython.display import display
from PIL import Image
import requests

# %%
with Image.open(
        requests.get(
            "http://huge:file@www.pythonchallenge.com/pc/return/screen15.jpg",
            stream=True).raw) as im:
    display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x608 at 0x2147357F070>

# %% [markdown]
# 提示为上图，以及F12两个注释：
# 1. `<!-- he ain't the youngest, he is the second -->`
# 2. `<!-- todo: buy flowers for tomorrow -->`

# %% [markdown]
# 整理线索：
#
# - 真正重要的是“明天”，即1月27号
# - 这一年的年份是1xx6年
# - 看右下角，这一天是闰年！
# - 这一天1月的星期应该与如图排列相同
#
# 明确查找方向：
#
# 查找1xx6年1月27号中为闰年，且当天为周二的年份。
#
# 查到后应该是不止一个答案，因为提示还说了要找第二新的年份。

# %%
import calendar
for year in range(1006, 2006, 10):
    if calendar.isleap(year) and calendar.weekday(year, 1, 27) == 1:
        print(year)
# Out:
# 1176
# 1356
# 1576
# 1756
# 1976

# %% [markdown]
# 排第二后的是1756年，那么1756年1月27号这一天发生了什么呢？
#
# 百度一下发现是莫扎特诞辰。
#
# 那么题目的“whom”就是指莫扎特了。
#
# 改url时发现Mozart，MOZART直接404了，看来以后是要默认全小写了。

# %% [markdown]
# ## Next Level:
#
# ### Url: http://huge:file@www.pythonchallenge.com/pc/return/mozart.html
